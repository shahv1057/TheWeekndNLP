# %%
from PyLyrics import *
wknd = 'The_Weeknd'
starboy = ["Starboy","Party Monster","False Alarm","Reminder","Rockin'","Secrets","True Colors","Stargirl Interlude","Sidewalks","Six Feet Under","Love to Lay","A Lonely Night","Attention","Ordinary Life","Nothing Without You","All I Know","Die For You","I Feel It Coming"]
trilogy =['High For This','What You Need',"House of Balloons / Glass Table Girls",'The Morning','Wicked Games','The Party & The After Party','Coming Down','Loft Music','The Knowing','Twenty Eight','Lonely Star','Life of the Party','Thursday','The Zone','The Birds Part One','The Birds Part Two','Gone','Rolling Stone','Heaven or Las Vegas','Valerie','D.D.','Montreal','Outside','XO / The Host','Initiation','Same Old Song','The Fall','Next','Echoes of Silence','Till Dawn (Here Comes The Sun)']
kissland = ['Professional','The Town',"Adaptation",'Love In The Sky','Belong To The World','Live For','Wanderlust','Kiss Land','Pretty','Tears In The Rain']
bbtm = ["Real Life","Losers","Tell Your Friends","Often","The Hills","Acquainted","Can't Feel My Face","Shameless","Earned It","In The Night","As You Are","Dark Times","Prisoner","Angel"]

# %%
import pandas as pd
df = pd.DataFrame()
lyr = []
alb = []
for song in starboy:
    lyr.append(PyLyrics.getLyrics(wknd,song))
    alb.append('Starboy')
for song in bbtm:
    lyr.append(PyLyrics.getLyrics(wknd,song))
    alb.append('Beauty Behind The Madness')
for song in kissland:
    lyr.append(PyLyrics.getLyrics(wknd,song))
    alb.append('Kiss Land')
for song in trilogy:
    lyr.append(PyLyrics.getLyrics(wknd,song))
    alb.append('Trilogy')
# Out:
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /Users/veeralshah/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/veeralshah/anaconda3/lib/python3.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
songs = starboy + bbtm + kissland + trilogy 
df['Album'] = alb
df['Song'] = songs
df['Lyrics'] = lyr

# %%
def clean_data(series):
    series = series.str.replace('[(),.?]','')
    series = series.str.replace('-|\s+',' ')
    series = series.str.lower()
    series = series.str.replace("n'[^a-z]","ng " )
    return series

# %%
clean_df = df
clean_df['Lyrics'] = clean_data(df['Lyrics'])
clean_df['LyricsSplit'] = clean_df['Lyrics'].apply(str.split)
clean_df['LyricsLen'] = clean_df['LyricsSplit'].apply(len)
clean_df['UniqueWordsSet'] = clean_df['LyricsSplit'].apply(set)
clean_df['UniqueWordsLen']= clean_df['UniqueWordsSet'].apply(len)
clean_df['%Unique'] = clean_df['UniqueWordsLen'] / clean_df['LyricsCount']

# %%
import wordcloud
import sklearn
import re
import string
import nltk

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
def word_counter(str1):
    count = {}
    for words in str1:
        if words in count.keys():
            count[words] +=1
        else:
            count[words] = 1
    return count

# %%
clean_df['WordCount'] = clean_df['LyricsSplit'].apply(word_counter) 
from collections import Counter 
clean_df['WordCount']
counter = Counter()
for worddict in clean_df['WordCount']:
    counter.update(worddict) 
result = dict(counter)   
#result = sorted(result.items(), key=lambda x: x[1], reverse=True)

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stopWords = list(stopwords.words('english'))
moreSW = ["i'm","i'll",'oh','ha','yeah','ooh',"i've",'hey','got','get',"'cause"]
stopWords.extend(moreSW)
for sw in stopWords:
    if sw in result.keys():
        del result[sw]
sorted(result.items(), key=lambda x: x[1], reverse=True)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/veeralshah/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [('know', 347),
#  ('love', 250),
#  ('girl', 239),
#  ('baby', 223),
#  ('feel', 144),
#  ('life', 125),
#  ('want', 123),
#  ('like', 111),
#  ('need', 107),
#  ('make', 104),
#  ("ain't", 99),
#  ('let', 91),
#  ('nothing', 89),
#  ('take', 84),
#  ('coming', 81),
#  ('go', 78),
#  ('always', 72),
#  ('keep', 69),
#  ('time', 68),
#  ('never', 67),
#  ('wanna', 67),
#  ('one', 64),
#  ('gone', 63),
#  ('say', 63),
#  ("we're", 61),
#  ('come', 56),
#  ("can't", 56),
#  ('see', 54),
#  ('tell', 54),
#  ('said', 53),
#  ('shit', 53),
#  ('would', 52),
#  ('real', 52),
#  ('good', 51),
#  ('could', 51),
#  ('even', 47),
#  ('fucking', 47),
#  ('money', 46),
#  ('right', 46),
#  ('live', 46),
#  ('somebody', 46),
#  ('man', 45),
#  ('night', 45),
#  ('alone', 44),
#  ('find', 44),
#  ('show', 44),
#  ('away', 44),
#  ('way', 44),
#  ('die', 42),
#  ('babe', 42),
#  ('talking', 39),
#  ("that's", 39),
#  ('body', 38),
#  ('touch', 38),
#  ('back', 37),
#  ('bring', 37),
#  ('day', 36),
#  ('fall', 36),
#  ('heart', 36),
#  ('little', 36),
#  ('something', 35),
#  ('us', 35),
#  ('every', 34),
#  ('fuck', 33),
#  ('think', 33),
#  ('call', 33),
#  ('la', 33),
#  ('leave', 32),
#  ('cause', 32),
#  ('work', 32),
#  ('next', 32),
#  ('gong', 32),
#  ('tryna', 31),
#  ('put', 31),
#  ('hard', 31),
#  ('hope', 31),
#  ('fun', 31),
#  ("'bout", 30),
#  ('loves', 30),
#  ("i'd", 30),
#  ('world', 30),
#  ('six', 29),
#  ('hold', 29),
#  ('made', 28),
#  ('done', 28),
#  ('niggas', 28),
#  ('give', 28),
#  ('ever', 28),
#  ('thursday', 28),
#  ('face', 27),
#  ('often', 27),
#  ('diamond', 27),
#  ('nigga', 26),
#  ('woke', 26),
#  ('eyes', 26),
#  ('around', 26),
#  ('true', 26),
#  ('everything', 26),
#  ('thing', 26),
#  ('ordinary', 26),
#  ('precious', 26),
#  ('name', 25),
#  ('told', 25),
#  ('nobody', 25),
#  ('long', 24),
#  ('though', 24),
#  ("i'ma", 24),
#  ('fucked', 24),
#  ('feet', 24),
#  ('times', 24),
#  ('understand', 23),
#  ('high', 23),
#  ('colors', 23),
#  ('thinking', 23),
#  ('without', 23),
#  ('top', 23),
#  ('really', 22),
#  ('false', 22),
#  ('alarm', 22),
#  ('attention', 22),
#  ('friends', 22),
#  ('pain', 21),
#  ('hear', 21),
#  ("i'mma", 21),
#  ("we'll", 21),
#  ('gonna', 21),
#  ("'em", 21),
#  ("there's", 21),
#  ('went', 21),
#  ('another', 21),
#  ('dirty', 21),
#  ('look', 20),
#  ('try', 20),
#  ('new', 20),
#  ('bitches', 20),
#  ('dark', 20),
#  ('better', 20),
#  ('home', 20),
#  ('well', 20),
#  ('probably', 20),
#  ('mind', 20),
#  ('feeling', 20),
#  ('diana', 20),
#  ('xo', 19),
#  ("he's", 19),
#  ('ride', 19),
#  ('gotta', 18),
#  ('floor', 18),
#  ('rocking', 18),
#  ('touching', 18),
#  ('living', 18),
#  ('going', 18),
#  ('thought', 18),
#  ('end', 17),
#  ('lie', 17),
#  ('pussy', 17),
#  ('scared', 17),
#  ('lay', 17),
#  ('belong', 17),
#  ('tried', 17),
#  ('bitch', 16),
#  ('looking', 16),
#  ('song', 16),
#  ('enough', 16),
#  ('much', 16),
#  ('believe', 16),
#  ('damn', 16),
#  ('till', 16),
#  ('tonight', 16),
#  ('inside', 16),
#  ('dancing', 16),
#  ('thang', 16),
#  ('house', 15),
#  ('popping', 15),
#  ('used', 15),
#  ('walk', 15),
#  ('sleep', 15),
#  ('trust', 15),
#  ('learned', 15),
#  ('lonely', 15),
#  ("she'll", 15),
#  ('saying', 15),
#  ('kill', 14),
#  ('girls', 14),
#  ('paranoid', 14),
#  ('fame', 14),
#  ('many', 14),
#  ('ask', 14),
#  ('worry', 14),
#  ('left', 14),
#  ('loved', 14),
#  ('things', 14),
#  ('might', 14),
#  ('ah', 13),
#  ('starboy', 13),
#  ('far', 13),
#  ('drink', 13),
#  ('ass', 13),
#  ('head', 13),
#  ('everybody', 13),
#  ('low', 13),
#  ('city', 13),
#  ('break', 13),
#  ('talk', 13),
#  ('apart', 13),
#  ('wrong', 13),
#  ('slow', 13),
#  ('pretty', 13),
#  ('still', 13),
#  ('okay', 13),
#  ('party', 13),
#  ('motherfucking', 12),
#  ('god', 12),
#  ('seen', 12),
#  ('roll', 12),
#  ('lies', 12),
#  ('seem', 12),
#  ('old', 12),
#  ('stay', 12),
#  ('moment', 12),
#  ('secrets', 12),
#  ('loving', 12),
#  ('phone', 12),
#  ('blame', 12),
#  ('last', 12),
#  ('care', 12),
#  ('please', 12),
#  ('dream', 12),
#  ('hurt', 11),
#  ('getting', 11),
#  ('cry', 11),
#  ('close', 11),
#  ('mine', 11),
#  ('trying', 11),
#  ('forget', 11),
#  ('people', 11),
#  ('stop', 11),
#  ('paper', 11),
#  ('room', 11),
#  ('worth', 11),
#  ('young', 11),
#  ('whoa', 11),
#  ('hate', 11),
#  ('pointless', 11),
#  ('happy', 11),
#  ('clothes', 11),
#  ('watch', 11),
#  ('707', 11),
#  ('boys', 11),
#  ('listen', 10),
#  ('mama', 10),
#  ('knew', 10),
#  ('thank', 10),
#  ('game', 10),
#  ('play', 10),
#  ('spend', 10),
#  ('past', 10),
#  ('rather', 10),
#  ("what's", 10),
#  ('tears', 10),
#  ('comes', 10),
#  ('step', 10),
#  ('already', 10),
#  ('qualified', 10),
#  ('deserve', 10),
#  ('louder', 10),
#  ('fikir', 10),
#  ('embrace', 10),
#  ('shame', 10),
#  ('place', 10),
#  ('yes', 10),
#  ('les', 10),
#  ('je', 10),
#  ('side', 9),
#  ('empty', 9),
#  ('test', 9),
#  ('open', 9),
#  ('friend', 9),
#  ('free', 9),
#  ('taking', 9),
#  ('broken', 9),
#  ('rain', 9),
#  ('lying', 9),
#  ('best', 9),
#  ('beautiful', 9),
#  ('calling', 9),
#  ('cold', 9),
#  ('mean', 9),
#  ('learn', 9),
#  ('become', 9),
#  ('ne', 9),
#  ('rolling', 9),
#  ('cup', 8),
#  ('star', 8),
#  ('lord', 8),
#  ('check', 8),
#  ('truth', 8),
#  ('lose', 8),
#  ('big', 8),
#  ('paint', 8),
#  ('waste', 8),
#  ('behind', 8),
#  ('picture', 8),
#  ('ways', 8),
#  ('five', 8),
#  ('pop', 8),
#  ('pretend', 8),
#  ('heaven', 8),
#  ('swear', 8),
#  ('heard', 8),
#  ('simple', 8),
#  ('rush', 8),
#  ('half', 8),
#  ('drugs', 8),
#  ('acquainted', 8),
#  ('since', 8),
#  ("who's", 8),
#  ('prisoner', 8),
#  ('lost', 8),
#  ('sky', 8),
#  ('control', 8),
#  ('fool', 8),
#  ('valerie', 8),
#  ('laisse', 8),
#  ('tomber', 8),
#  ('filles', 8),
#  ('jour', 8),
#  ('pleurerai', 8),
#  ('pas', 8),
#  ('two', 7),
#  ('whole', 7),
#  ('cut', 7),
#  ('hit', 7),
#  ('type', 7),
#  ('smoke', 7),
#  ('blow', 7),
#  ('boy', 7),
#  ('whip', 7),
#  ('pour', 7),
#  ('making', 7),
#  ('sure', 7),
#  ('woo', 7),
#  ('wants', 7),
#  ('lust', 7),
#  ('hide', 7),
#  ('flow', 7),
#  ('sidewalks', 7),
#  ('lead', 7),
#  ('turn', 7),
#  ('crying', 7),
#  ('mouth', 7),
#  ('full', 7),
#  ('remember', 7),
#  ('pills', 7),
#  ('felt', 7),
#  ('smile', 7),
#  ('feels', 7),
#  ('bad', 7),
#  ('slip', 7),
#  ('glass', 7),
#  ('motive', 7),
#  ('monday', 7),
#  ('bird', 7),
#  ('shoes', 6),
#  ('switch', 6),
#  ('pull', 6),
#  ('brand', 6),
#  ('mixing', 6),
#  ('meet', 6),
#  ('nose', 6),
#  ('seems', 6),
#  ('weed', 6),
#  ('bag', 6),
#  ('singing', 6),
#  ('neck', 6),
#  ('sex', 6),
#  ('catch', 6),
#  ('lover', 6),
#  ('shine', 6),
#  ('street', 6),
#  ('saved', 6),
#  ('late', 6),
#  ('dead', 6),
#  ('club', 6),
#  ('na', 6),
#  ('cum', 6),
#  ('chose', 6),
#  ('trade', 6),
#  ('pick', 6),
#  ('miss', 6),
#  ('perfect', 6),
#  ('makes', 6),
#  ('sense', 6),
#  ('white', 6),
#  ('town', 6),
#  ('downtown', 6),
#  ('almost', 6),
#  ('zone', 6),
#  ('glad', 6),
#  ('numb', 6),
#  ('"don\'t', 6),
#  ('earned', 6),
#  ('kind', 6),
#  ('light', 6),
#  ('dreams', 6),
#  ('closer', 6),
#  ('nights', 6),
#  ('liked', 6),
#  ('provide', 6),
#  ('days', 6),
#  ('wanderlust', 6),
#  ('morning', 6),
#  ("c'est", 6),
#  ('ce', 6),
#  ('promise', 6),
#  ('door', 6),
#  ('taste', 6),
#  ('tables', 6),
#  ('tuesday', 6),
#  ('friday', 6),
#  ('saturday', 6),
#  ('sunday', 6),
#  ('kiss', 6),
#  ('red', 5),
#  ('year', 5),
#  ('week', 5),
#  ('clean', 5),
#  ('pray', 5),
#  ('rings', 5),
#  ('faded', 5),
#  ('couple', 5),
#  ('shake', 5),
#  ('either', 5),
#  ('calls', 5),
#  ('crazy', 5),
#  ("let's", 5),
#  ('else', 5),
#  ('different', 5),
#  ('problem', 5),
#  ('pay', 5),
#  ('sun', 5),
#  ('twenty', 5),
#  ('arms', 5),
#  ('came', 5),
#  ('begun', 5),
#  ('start', 5),
#  ('led', 5),
#  ('apologize', 5),
#  ('tongue', 5),
#  ('run', 5),
#  ('regret', 5),
#  ('fix', 5),
#  ('cash', 5),
#  ('change', 5),
#  ('push', 5),
#  ('"i', 5),
#  ('teach', 5),
#  ('prove', 5),
#  ('throne', 5),
#  ('minute', 5),
#  ('road', 5),
#  ('yenefikir', 5),
#  ('dangerous', 5),
#  ('born', 5),
#  ('falling', 5),
#  ('relate', 5),
#  ('shy', 5),
#  ('sip', 5),
#  ('mix', 5),
#  ('wait', 5),
#  ("qu'on", 5),
#  ('là', 5),
#  ('adjust', 5),
#  ('hand', 5),
#  ('breathe', 5),
#  ('weeknd:', 5),
#  ('north', 5),
#  ('finished', 5),
#  ('wednesday', 5),
#  ('falls', 5),
#  ('lot', 5),
#  ('20', 4),
#  ('racks', 4),
#  ('table', 4),
#  ('hearing', 4),
#  ('blue', 4),
#  ('took', 4),
#  ('crib', 4),
#  ('great', 4),
#  ('pole', 4),
#  ('grind', 4),
#  ('line', 4),
#  ('three', 4),
#  ('outside', 4),
#  ('safe', 4),
#  ('bathroom', 4),
#  ('heel', 4),
#  ('devil', 4),
#  ('signs', 4),
#  ('soul', 4),
#  ('hair', 4),
#  ('fly', 4),
#  ('pow!', 4),
#  ('straight', 4),
#  ('bed', 4),
#  ('ones', 4),
#  ('uh', 4),
#  ("it'd", 4),
#  ('stargirl', 4),
#  ('streets', 4),
#  ('wish', 4),
#  ('queen', 4),
#  ('showed', 4),
#  ('land', 4),
#  ('louis', 4),
#  ('crew', 4),
#  ('murder', 4),
#  ('lately', 4),
#  ('someone', 4),
#  ('twice', 4),
#  ('closed', 4),
#  ('spill', 4),
#  ('bougie', 4),
#  ('first', 4),
#  ('working', 4),
#  ('set', 4),
#  ('woman', 4),
#  ('choose', 4),
#  ('taught', 4),
#  ('lines', 4),
#  ('four', 4),
#  ('choices', 4),
#  ('sleeping', 4),
#  ('saw', 4),
#  ('fast', 4),
#  ('sins', 4),
#  ('least', 4),
#  ('expected', 4),
#  ('anything', 4),
#  ('dollar', 4),
#  ('bills', 4),
#  ('weak', 4),
#  ('scars', 4),
#  ('honest', 4),
#  ('mother', 4),
#  ("could've", 4),
#  ('addiction', 4),
#  ('addicted', 4),
#  ('decisions', 4),
#  ('angel', 4),
#  ('wings', 4),
#  ('meant', 4),
#  ('da', 4),
#  ('professional', 4),
#  ('stronger', 4),
#  ('bet', 4),
#  ('gave', 4),
#  ('adapted', 4),
#  ('burn', 4),
#  ('raw', 4),
#  ('sheets', 4),
#  ("nobody's", 4),
#  ('mistreat', 4),
#  ('shot', 4),
#  ('forgot', 4),
#  ('hurts', 4),
#  ('ready', 4),
#  ('must', 4),
#  ('wet', 4),
#  ('cups', 4),
#  ('folding', 4),
#  ('beg', 4),
#  ('hoo', 4),
#  ('pass', 4),
#  ('un', 4),
#  ('toi', 4),
#  ('laissera', 4),
#  ('oui', 4),
#  ("j'ai", 4),
#  ('pleuré', 4),
#  ('mais', 4),
#  ('non', 4),
#  ('[x4]', 4),
#  ('worst', 3),
#  ('tease', 3),
#  ('centerpiece', 3),
#  ('ebony', 3),
#  ('ivory', 3),
#  ('skinny', 3),
#  ('pieces', 3),
#  ('aid', 3),
#  ('shade', 3),
#  ('style', 3),
#  ('lane', 3),
#  ('bought', 3),
#  ('cars', 3),
#  ('bump', 3),
#  ('lips', 3),
#  ('dick', 3),
#  ('spot', 3),
#  ('gold', 3),
#  ('gets', 3),
#  ('diamonds', 3),
#  ('forever', 3),
#  ('busy', 3),
#  ('black', 3),
#  ('potion', 3),
#  ('knows', 3),
#  ('codeine', 3),
#  ('burning', 3),
#  ("'round", 3),
#  ('women', 3),
#  ("nothing's", 3),
#  ('hoo!', 3),
#  ('energy', 3),
#  ('brings', 3),
#  ('ecstasy', 3),
#  ('reckless', 3),
#  ('hey!', 3),
#  ('questions', 3),
#  ('confessions', 3),
#  ('vision', 3),
#  ('screaming', 3),
#  ('single', 3),
#  ('legs', 3),
#  ('rock', 3),
#  ('bend', 3),
#  ('use', 3),
#  ('together', 3),
#  ('strong', 3),
#  ('notice', 3),
#  ('wheel', 3),
#  ('cross', 3),
#  ('sorry', 3),
#  ('realized', 3),
#  ('stand', 3),
#  ('eye', 3),
#  ('future', 3),
#  ('broke', 3),
#  ('blood', 3),
#  ('ay', 3),
#  ('pocket', 3),
#  ('trigger', 3),
#  ('beside', 3),
#  ('distance', 3),
#  ("it'll", 3),
#  ('fight', 3),
#  ('called', 3),
#  ('move', 3),
#  ('owe', 3),
#  ('testing', 3),
#  ('destined', 3),
#  ('trill', 3),
#  ('hoes', 3),
#  ('killing', 3),
#  ('driving', 3),
#  ('guess', 3),
#  ('"often"', 3),
#  ('rode', 3),
#  ('wave', 3),
#  ('"not', 3),
#  ('often"', 3),
#  ('drinking', 3),
#  ('smoking', 3),
#  ("night's", 3),
#  ('found', 3),
#  ('ewedeshalo', 3),
#  ('fell', 3),
#  ('complacent', 3),
#  ('caught', 3),
#  ('keeps', 3),
#  ('yet', 3),
#  ('it"', 3),
#  ('more"', 3),
#  ('deep', 3),
#  ('begging', 3),
#  ('became', 3),
#  ('unexpected', 3),
#  ("moment's", 3),
#  ('hears', 3),
#  ('relieve', 3),
#  ('crawling', 3),
#  ('knees', 3),
#  ('forced', 3),
#  ('flaws', 3),
#  ("man's", 3),
#  ('problems', 3),
#  ('maybe', 3),
#  ('selfish', 3),
#  ('aw', 3),
#  ('ago', 3),
#  ('decide', 3),
#  ('sophisticated', 3),
#  ('holding', 3),
#  ('crown', 3),
#  ('goes', 3),
#  ('tomorrow', 3),
#  ('turning', 3),
#  ('confidence', 3),
#  ('domesticate', 3),
#  ('dawg', 3),
#  ('wall', 3),
#  ('strip', 3),
#  ('telling', 3),
#  ('bigger', 3),
#  ('tall', 3),
#  ('months', 3),
#  ('harder', 3),
#  ('exactly', 3),
#  ('à', 3),
#  ('recollection', 3),
#  ('sad', 3),
#  ('store', 3),
#  ('tight', 3),
#  ('recognize', 3),
#  ('window', 3),
#  ('wanted', 3),
#  ('dub', 3),
#  ('nice', 3),
#  ('exist', 3),
#  ('doors', 3),
#  ('kinda', 3),
#  ('virgin', 3),
#  ('chance', 3),
#  ('drop', 3),
#  ('dance', 3),
#  ('supply', 3),
#  ('potential', 3),
#  ('drowning', 3),
#  ('x2', 3),
#  ('brain', 3),
#  ('seat', 3),
#  ('loft', 3),
#  ('ground', 3),
#  ('ovo', 3),
#  ('pleading', 3),
#  ('peak', 3),
#  ('point', 2),
#  ('yah', 2),
#  ('main', 2),
#  ('league', 2),
#  ('pockets', 2),
#  ('king', 2),
#  ('wagon', 2),
#  ('shop', 2),
#  ('roof', 2),
#  ('loose', 2),
#  ('angelina', 2),
#  ('selena', 2),
#  ('row', 2),
#  ('reach', 2),
#  ('reason', 2),
#  ('realest', 2),
#  ('crowding', 2),
#  ('space', 2),
#  ('dresser', 2),
#  ('chains', 2),
#  ('wrapped', 2),
#  ('camera', 2),
#  ('philosophy', 2),
#  ('haunts', 2),
#  ('constantly', 2),
#  ('inch', 2),
#  ('wide', 2),
#  ('dolla', 2),
#  ('bill', 2),
#  ('chase', 2),
#  ('hearts', 2),
#  ('sweat', 2),
#  ('hits', 2),
#  ('kids', 2),
#  ('goddamn', 2),
#  ('choice', 2),
#  ('remind', 2),
#  ('wetter', 2),
#  ('dope', 2),
#  ('sipping', 2),
#  ('bleed', 2),
#  ('og', 2),
#  ('wrap', 2),
#  ('mattress', 2),
#  ('wear', 2),
#  ('liquor', 2),
#  ('mixed', 2),
#  ('beat', 2),
#  ('guys', 2),
#  ('wipe', 2),
#  ('accept', 2),
#  ('keeper', 2),
#  ('position', 2),
#  ('ran', 2),
#  ('homeless', 2),
#  ('stress', 2),
#  ('rich', 2),
#  ('pulling', 2),
#  ('grinding', 2),
#  ('lamar', 2),
#  ('summer', 2),
#  ('bae', 2),
#  ('tripping', 2),
#  ('eight', 2),
#  ('reminisce', 2),
#  ('repent', 2),
#  ('hang', 2),
#  ('moon', 2),
#  ('greatest', 2),
#  ('feelings', 2),
#  ('suit', 2),
#  ('lick', 2),
#  ('candy', 2),
#  ('family', 2),
#  ('fancy', 2),
#  ('bentley', 2),
#  ('vuitton', 2),
#  ('husband', 2),
#  ('lusting', 2),
#  ('trap', 2),
#  ('waiting', 2),
#  ("love's", 2),
#  ('strangers', 2),
#  ('rethink', 2),
#  ('decision', 2),
#  ('calm', 2),
#  ('teeth', 2),
#  ('drive', 2),
#  ('letting', 2),
#  ('whe', 2),
#  ('"it\'s', 2),
#  ('say"', 2),
#  ('kept', 2),
#  ('45', 2),
#  ('edge', 2),
#  ('woah', 2),
#  ('question', 2),
#  ('hesitate', 2),
#  ('reasons', 2),
#  ('doubt', 2),
#  ('eat', 2),
#  ('overflow', 2),
#  ('conceited', 2),
#  ('titties', 2),
#  ('sneak', 2),
#  ('finding', 2),
#  ('thoughts', 2),
#  ("'specially", 2),
#  ('afford', 2),
#  ('oh!', 2),
#  ('blaming', 2),
#  ('changed', 2),
#  ('destructive', 2),
#  ('seemed', 2),
#  ('misery', 2),
#  ('losers', 2),
#  ('school', 2),
#  ('count', 2),
#  ("stupid's", 2),
#  ('you"', 2),
#  ('grown', 2),
#  ("we've", 2),
#  ('mess', 2),
#  ('stopping', 2),
#  ('chasing', 2),
#  ('coke', 2),
#  ('gimme', 2),
#  ('imma', 2),
#  ('beginning', 2),
#  ('mia', 2),
#  ('cali', 2),
#  ('mission', 2),
#  ('west', 2),
#  ('roam', 2),
#  ('sing', 2),
#  ('flip', 2),
#  ('pictures', 2),
#  ('matter', 2),
#  ('send', 2),
#  ('hills', 2),
#  ('judge', 2),
#  ('bout', 2),
#  ('putting', 2),
#  ("'way", 2),
#  ("'get", 2),
#  ("90's", 2),
#  ('death', 2),
#  ('needed', 2),
#  ('favorite', 2),
#  ('babygirl', 2),
#  ('capable', 2),
#  ('riveting', 2),
#  ('wake', 2),
#  ('running', 2),
#  ('circles', 2),
#  ('promising', 2),
#  ('dripping', 2),
#  ('promises', 2),
#  ('amazing', 2),
#  ('lesson', 2),
#  ('special', 2),
#  ('sin', 2),
#  ('emotions', 2),
#  ('dangerously', 2),
#  ('happiness', 2),
#  ('quit', 2),
#  ('years', 2),
#  ('everywhere', 2),
#  ("how'd", 2),
#  ('rely', 2),
#  ('tour', 2),
#  ('luck', 2),
#  ('anyway', 2),
#  ('morals', 2),
#  ('pure', 2),
#  ('offered', 2),
#  ("world's", 2),
#  ('flying', 2),
#  ('shows', 2),
#  ('lifeless', 2),
#  ('whatever', 2),
#  ('sitting', 2),
#  ('fake', 2),
#  ("y'all", 2),
#  ('spent', 2),
#  ('story', 2),
#  ('hips', 2),
#  ('waist', 2),
#  ('scream', 2),
#  ('henny', 2),
#  ('share', 2),
#  ("they're", 2),
#  ('idea', 2),
#  ('issue', 2),
#  ('hundred', 2),
#  ("'head", 2),
#  ('kisses', 2),
#  ('cards', 2),
#  ('finish', 2),
#  ('hot', 2),
#  ("life's", 2),
#  ('staring', 2),
#  ('walls', 2),
#  ('21', 2),
#  ('seeing', 2),
#  ('round', 2),
#  ('worried', 2),
#  ('driver', 2),
#  ('dawn', 2),
#  ('russian', 2),
#  ('likes', 2),
#  ('grills', 2),
#  ('certain', 2),
#  ('expectations', 2),
#  ('art', 2),
#  ('une', 2),
#  ('de', 2),
#  ('dans', 2),
#  ('ans', 2),
#  ("gon'stop", 2),
#  ('drug', 2),
#  ('veins', 2),
#  ('boots', 2),
#  ('level', 2),
#  ('siouxsie', 2),
#  ('sioux', 2),
#  ('music', 2),
#  ('quicker', 2),
#  ('shift', 2),
#  ('seven', 2),
#  ('lady', 2),
#  ('band', 2),
#  ('act', 2),
#  ('deal', 2),
#  ('dude', 2),
#  ('order', 2),
#  ('month', 2),
#  ('warn', 2),
#  ('twisted', 2),
#  ('foreign', 2),
#  ('leaning', 2),
#  ('drank', 2),
#  ('words', 2),
#  ('warning', 2),
#  ('alright', 2),
#  ('v', 2),
#  ('tatts', 2),
#  ('pluck', 2),
#  ('feathers', 2),
#  ('birds', 2),
#  ('messing', 2),
#  ('rolled', 2),
#  ("party's", 2),
#  ('especially', 2),
#  ('unless', 2),
#  ('keys', 2),
#  ('middle', 2),
#  ('washing', 2),
#  ('hiding', 2),
#  ('smiles', 2),
#  ('twist', 2),
#  ('ahead', 2),
#  ('nothings', 2),
#  ...]

# %%
data_dtm = pd.DataFrame(data_cv.toarray(),columns = cv.get_feature_names())
data_dtm.index = clean_data.Album

# %%
data_dtm = data_dtm.transpose()

# %%
data_dtm

# %%
top30 = {}
dftest = data_dtm.sort_values(by = "Beauty Behind The Madness",ascending = "False")

# %%
top_dict = {}
for n in data_dtm:
    top30 = data_dtm[n].sort_values(ascending = False).head(30)
    top_dict[n] = list(zip(top30.index, top30.values))
    #top_dict[n] = data_
print (top_dict.values())
# Out:
# dict_values([[('im', 82), ('love', 81), ('know', 66), ('yeah', 53), ('life', 50), ('ill', 48), ('real', 43), ('dont', 39), ('somebody', 38), ('girl', 35), ('cause', 30), ('baby', 28), ('thats', 27), ('youre', 27), ('oh', 26), ('time', 24), ('hope', 23), ('feel', 22), ('got', 22), ('tell', 20), ('times', 20), ('make', 18), ('heart', 18), ('like', 17), ('dark', 16), ('want', 16), ('said', 15), ('say', 15), ('friends', 15), ('just', 15)], [('love', 58), ('girl', 38), ('shit', 33), ('im', 30), ('make', 29), ('little', 29), ('feel', 28), ('live', 28), ('diamond', 27), ('youre', 26), ('precious', 25), ('just', 24), ('away', 24), ('let', 24), ('dont', 24), ('like', 23), ('world', 22), ('know', 22), ('cause', 20), ('leave', 18), ('come', 17), ('oh', 16), ('thang', 16), ('youve', 16), ('die', 15), ('got', 15), ('ive', 14), ('belong', 12), ('tried', 12), ('id', 11)], [('know', 155), ('hey', 84), ('im', 83), ('feel', 73), ('just', 72), ('yeah', 67), ('dont', 67), ('coming', 61), ('nothin', 58), ('girl', 54), ('life', 46), ('baby', 45), ('oh', 42), ('youre', 40), ('love', 39), ('babe', 37), ('aint', 35), ('cause', 33), ('loves', 30), ('got', 28), ('like', 28), ('time', 27), ('woke', 26), ('ordinary', 26), ('say', 25), ('die', 25), ('colors', 23), ('true', 23), ('false', 22), ('alarm', 22)], [('baby', 145), ('im', 139), ('girl', 112), ('got', 111), ('know', 104), ('dont', 103), ('oh', 96), ('want', 90), ('just', 85), ('love', 72), ('need', 71), ('cause', 70), ('yeah', 54), ('let', 50), ('aint', 47), ('youre', 47), ('make', 43), ('like', 43), ('gone', 39), ('money', 35), ('ill', 35), ('wanna', 34), ('la', 32), ('ooh', 31), ('thursday', 29), ('fun', 29), ('bring', 28), ('right', 28), ('fall', 25), ('ive', 24)]])

# %%
wc = wordcloud.WordCloud(background_color = "white",colormap = "Dark2",max_font_size= 150,random_state=42)

# %%
clean_data = clean_data.set_index('Album')

# %%
import matplotlib.pyplot as plt
for n in clean_data.index:
    print (n)
    wc.generate(clean_data.loc[n,'Lyrics'])
    plt.figure()
    plt.imshow(wc, interpolation='bilinear')
    plt.axis('off')
    plt.title(n)
# Out:
# Beauty Behind The Madness
# Kiss Land
# Starboy
# Trilogy

# %%
for n in top_dict:
    wc.generate_from_frequencies(dict(top_dict[n]))
    plt.figure()
    plt.imshow(wc, interpolation='bilinear')
    plt.axis('off')
    plt.title(n)

# %%
clean_data
# Out:
#                                                                       Lyrics
# Album
# Beauty Behind The Madness  tell em this boy wasnt made for lovin tell em ...
# Kiss Land                  its ideal you need someone to tell you how to ...
# Starboy                    im tryna put you in the worst mood ah p1 clean...
# Trilogy                    you dont know whats in store but you know what...

# %%
from textblob import TextBlob
pol = []
sub = []
for n in range(0,len(clean_df.index)):
    pol.append(TextBlob(clean_df.loc[n,"Lyrics"]).sentiment.polarity)
    sub.append(TextBlob(clean_df.loc[n,"Lyrics"]).sentiment.subjectivity)
clean_df['Polarity'] = pol
clean_df['Subjectivity'] = sub

# %%
clean_df.head()
# Out:
#      Album           Song                                             Lyrics  \
# 0  Starboy        Starboy  i'm tryna put you in the worst mood ah p1 clea...
# 1  Starboy  Party Monster  i'm good i'm good i'm great know it's been a w...
# 2  Starboy    False Alarm  bathroom stalls for the powder nose she loves ...
# 3  Starboy       Reminder  recommend play my song on the radio you too bu...
# 4  Starboy        Rockin'  people always talk about the ones that got awa...
#
#                                       UniqueWordsSet  UniqueWordsCount  \
# 0  {cry, done, face, pumping, all, pieces, that's...               172
# 1  {i've, realest, spot, all, it's, ass, reason, ...               106
# 2  {bathroom, all, red, it's, 'bout, love, hearts...                87
# 3  {lambo, globe, teen, keep, face, 'round, all, ...               207
# 4  {life, all, go!, acting, 'bout, hey!, baby, ju...                99
#
#                                          LyricsSplit  LyricsCount   %Unique  \
# 0  [i'm, tryna, put, you, in, the, worst, mood, a...          609  0.282430
# 1  [i'm, good, i'm, good, i'm, great, know, it's,...          646  0.164087
# 2  [bathroom, stalls, for, the, powder, nose, she...          332  0.262048
# 3  [recommend, play, my, song, on, the, radio, yo...          461  0.449024
# 4  [people, always, talk, about, the, ones, that,...          401  0.246883
#
#                                            WordCount  Polarity  Subjectivity
# 0  {'i'm': 9, 'tryna': 1, 'put': 1, 'you': 9, 'in...  0.131546      0.505317
# 1  {'i'm': 24, 'good': 8, 'great': 4, 'know': 25,...  0.372623      0.435371
# 2  {'bathroom': 1, 'stalls': 1, 'for': 3, 'the': ... -0.176667      0.565983
# 3  {'recommend': 1, 'play': 1, 'my': 10, 'song': ...  0.060696      0.408893
# 4  {'people': 1, 'always': 2, 'talk': 1, 'about':...  0.129412      0.308824

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
for n in df.index:
    pol1 = df.loc[n,'%Unique']
    sub1 = df.loc[n,'LyricsCount']
    plt.scatter(pol1,sub1, color = "Green")
    plt.text(pol1+.001,sub1+.001,df.loc[n,'Song'], fontsize = 7)
    plt.xlabel('%Unique')
    plt.ylabel('LyricsCount')

# %%
import seaborn as sns
sns.set_style('darkgrid')
sns.set_palette('RdBu',4)
sns.set(rc={'figure.figsize':(11.7,8.27)})
plot1 = sns.scatterplot(x='%Unique',y='LyricsCount',data=clean_df,hue='Album',s=150,palette='RdBu')
for n in clean_df.index:
    x1 = df.loc[n,'%Unique']
    y1 = df.loc[n,'LyricsCount']
    plot1.text(x1+.004,y1+.004,df.loc[n,'Song'],fontsize=10,weight='semibold')

# %%
len(clean_df)
# Out:
# 72
